# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
from darts import TimeSeries
from darts.models import RandomForestModel
from darts.metrics import mape, mae, mse
from darts.utils.model_selection import train_test_split
from darts.dataprocessing.transformers import Scaler, Diff
from darts.utils.missing_values import fill_missing_values
import warnings
import traceback

warnings.filterwarnings("ignore")

# ============================================================
# ⚙️ CONFIGURATION
# ============================================================

BASE_PATH = r"C:\wilson\Thesis\Data\final_data"
RESULT_PATH = r"C:\wilson\Thesis\Results"
PREDICTION_DIR = os.path.join(RESULT_PATH, "rf_predictionsss_final")
os.makedirs(RESULT_PATH, exist_ok=True)
os.makedirs(PREDICTION_DIR, exist_ok=True)

DATA_FILES = {
    "ihsg": {"path": os.path.join(BASE_PATH, "ihsg_final.csv"), "target_col": "close_ihsg"},
    "lq45": {"path": os.path.join(BASE_PATH, "lq45_final.csv"), "target_col": "close_lq45"},
    "kompas100": {"path": os.path.join(BASE_PATH, "kompas100_final.csv"), "target_col": "close_kompas100"},
}

COVARIATES_NONE = []
COVARIATES_DOMESTIC = ["close_inflation", "close_gdp", "close_cpi", "close_unemployment"]
COVARIATES_GLOBAL = ["close_usd", "close_brent", "close_wti"]
COVARIATES_ALL = COVARIATES_DOMESTIC + COVARIATES_GLOBAL
COVARIATE_SETS = {
    "None": COVARIATES_NONE,
    "Domestic": COVARIATES_DOMESTIC,
    "Global": COVARIATES_GLOBAL,
    "All": COVARIATES_ALL,
    "Inflation": ["close_inflation"],
    "GDP": ["close_gdp"],
    "CPI": ["close_cpi"],
    "Unemployment": ["close_unemployment"],
    "USD": ["close_usd"],
    "Brent": ["close_brent"],
    "WTI": ["close_wti"]
}

SCENARIOS = {
    "Short-Term Sprint": {"window": 30, "horizon": 1},
    "Medium-Term Pace": {"window": 60, "horizon": 5},
    "Long-Term Marathon": {"window": 90, "horizon": 10}
}

RF_CONFIG = {
    "n_estimators": 100,
    "max_depth": 5,
    "max_samples": 0.7,
    "n_jobs": -1,
    "random_state": 42
}

# ============================================================
# 🧩 FUNCTIONS
# ============================================================

def load_data(path, target_col):
    df = pd.read_csv(path)
    df["date"] = pd.to_datetime(df["date"])
    df = df.sort_values("date").reset_index(drop=True)
    return df

def to_series(df, target_col, covariates):
    target_series = TimeSeries.from_dataframe(df, time_col="date", value_cols=target_col, fill_missing_dates=True, freq="B")
    target_series = fill_missing_values(target_series)
    covariate_series = None
    if covariates:
        covariate_series = TimeSeries.from_dataframe(df, time_col="date", value_cols=covariates, fill_missing_dates=True, freq="B")
        covariate_series = fill_missing_values(covariate_series)
    return target_series, covariate_series

def train_and_evaluate_rf(target_series, covariate_series, window, horizon):
    # 1. Split Data
    train, val = train_test_split(target_series, test_size=0.2)
    
    # 2. Log-Transform & Differencing
    ts_log = target_series.map(np.log)
    differencer = Diff(lags=1)
    ts_log_diff = differencer.fit_transform(ts_log)
    
    # 3. Scaling
    scaler = Scaler()
    ts_scaled = scaler.fit_transform(ts_log_diff)
    train_scaled, val_scaled = ts_scaled.split_before(val.start_time())
    
    # Covariates
    cov_transformed = None
    if covariate_series:
        cov_scaler = Scaler()
        cov_transformed = cov_scaler.fit_transform(covariate_series)

    # 4. Train Model
    model = RandomForestModel(
        lags=window,
        lags_past_covariates=window if covariate_series else None,
        output_chunk_length=horizon,
        **RF_CONFIG
    )
    model.fit(train_scaled, past_covariates=cov_transformed)

    # 5. Block-by-Block Forecast
    forecast_list_scaled = model.historical_forecasts(
        series=ts_scaled,
        past_covariates=cov_transformed,
        start=val.start_time(),
        forecast_horizon=horizon,
        stride=horizon,          
        retrain=False,
        last_points_only=False,  
        verbose=False
    )

    if isinstance(forecast_list_scaled, TimeSeries):
        forecast_list_scaled = [forecast_list_scaled]

    # 6. Reconstruction Loop
    all_pred_dates = []
    all_pred_prices = []

    for chunk_scaled in forecast_list_scaled:
        # A. Inverse Scale
        chunk_diff_log = scaler.inverse_transform(chunk_scaled)
        chunk_dates = chunk_diff_log.time_index
        chunk_log_returns = chunk_diff_log.values().flatten()

        # B. Anchor Price
        start_date = chunk_dates[0]
        idx = target_series.get_index_at_point(start_date)
        
        # C. Reconstruct
        anchor_log_price = ts_log[idx-1].values()[0][0]
        chunk_log_prices = anchor_log_price + np.cumsum(chunk_log_returns)
        chunk_prices = np.exp(chunk_log_prices)
        
        all_pred_dates.extend(chunk_dates)
        all_pred_prices.extend(chunk_prices)

    # 7. Metrics & DataFrame
    prediction_df = pd.DataFrame({
        "date": pd.to_datetime(all_pred_dates),
        "predicted": all_pred_prices
    })
    
    full_df = target_series.to_dataframe().reset_index()
    full_df.columns = ["date", "actual"]
    
    final_df = pd.merge(full_df, prediction_df, on="date", how="left")
    final_df["train_flag"] = 0
    final_df.loc[final_df["date"] <= train.end_time(), "train_flag"] = 1

    # Evaluate
    eval_df = final_df.dropna(subset=["predicted"])
    y_true = eval_df["actual"].values
    y_pred = eval_df["predicted"].values
    
    mape_val = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    mae_val = np.mean(np.abs(y_true - y_pred))
    mse_val = np.mean((y_true - y_pred)**2)

    return mape_val, mae_val, mse_val, final_df

# ============================================================
# 🚀 MAIN LOOP (MODIFIED)
# ============================================================

results = []
start_time = datetime.now()
print(f"📅 Experiment started: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

for target_key, info in DATA_FILES.items():
    df = load_data(info["path"], info["target_col"])
    print(f"\n📂 Processing {target_key.upper()}")

    for scenario_name, sc in SCENARIOS.items():
        window, horizon = sc["window"], sc["horizon"]

        for cov_name, cov_list in COVARIATE_SETS.items():
            print(f"[▶] {target_key.upper()} | {scenario_name} | Covariates={cov_name}")
            try:
                target_series, covariate_series = to_series(df, info["target_col"], cov_list)
                
                mape_val, mae_val, mse_val, pred_df = train_and_evaluate_rf(
                    target_series, covariate_series, window, horizon
                )
                
                # --- ✨ MODIFICATION START ✨ ---
                # Add metadata columns so the Dashboard can read them directly!
                pred_df["covariate_set"] = cov_name
                pred_df["target"] = target_key
                pred_df["scenario"] = scenario_name
                # --- ✨ MODIFICATION END ✨ ---

                fname = f"rf_pred_{target_key}_{scenario_name.replace(' ','_')}_{cov_name}.csv"
                pred_df.to_csv(os.path.join(PREDICTION_DIR, fname), index=False)
                
                results.append({
                    "Target": target_key.upper(),
                    "Scenario": scenario_name,
                    "Covariates": cov_name,
                    "Window": window,
                    "Horizon": horizon,
                    "MAPE": round(mape_val, 4),
                    "MAE": round(mae_val, 4),
                    "MSE": round(mse_val, 4)
                })
                print(f"   ✅ MAPE={mape_val:.2f}% | MAE={mae_val:.2f}")
                
            except Exception as e:
                traceback.print_exc()
                print(f"   ❌ Error: {e}")
                results.append({"Target": target_key, "Scenario": scenario_name, "Error": str(e)})

results_df = pd.DataFrame(results)
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
out_path = os.path.join(RESULT_PATH, f"rf_results_summary_{timestamp}.csv")
results_df.to_csv(out_path, index=False)
print(f"\n✅ All experiments done! Saved to {out_path}")
# Out:
# 📅 Experiment started: 2026-01-06 21:41:44
#
# 📂 Processing IHSG
# [▶] IHSG | Short-Term Sprint | Covariates=None
#    ✅ MAPE=0.54% | MAE=37.81
# [▶] IHSG | Short-Term Sprint | Covariates=Domestic
#    ✅ MAPE=0.54% | MAE=37.82
# [▶] IHSG | Short-Term Sprint | Covariates=Global
#    ✅ MAPE=0.55% | MAE=39.02
# [▶] IHSG | Short-Term Sprint | Covariates=All
#    ✅ MAPE=0.55% | MAE=39.06
# [▶] IHSG | Short-Term Sprint | Covariates=Inflation
#    ✅ MAPE=0.54% | MAE=37.78
# [▶] IHSG | Short-Term Sprint | Covariates=GDP
#    ✅ MAPE=0.54% | MAE=37.80
# [▶] IHSG | Short-Term Sprint | Covariates=CPI
#    ✅ MAPE=0.54% | MAE=37.81
# [▶] IHSG | Short-Term Sprint | Covariates=Unemployment
#    ✅ MAPE=0.54% | MAE=37.79
# [▶] IHSG | Short-Term Sprint | Covariates=USD
#    ✅ MAPE=0.55% | MAE=38.71
# [▶] IHSG | Short-Term Sprint | Covariates=Brent
#    ✅ MAPE=0.54% | MAE=37.81
# [▶] IHSG | Short-Term Sprint | Covariates=WTI
#    ✅ MAPE=0.54% | MAE=37.81
# [▶] IHSG | Medium-Term Pace | Covariates=None
#    ✅ MAPE=0.83% | MAE=58.70
# [▶] IHSG | Medium-Term Pace | Covariates=Domestic
#    ✅ MAPE=0.84% | MAE=58.81
# [▶] IHSG | Medium-Term Pace | Covariates=Global
#    ✅ MAPE=0.84% | MAE=59.14
# [▶] IHSG | Medium-Term Pace | Covariates=All
#    ✅ MAPE=0.84% | MAE=58.86
# [▶] IHSG | Medium-Term Pace | Covariates=Inflation
#    ✅ MAPE=0.83% | MAE=58.71
# [▶] IHSG | Medium-Term Pace | Covariates=GDP
#    ✅ MAPE=0.84% | MAE=58.81
# [▶] IHSG | Medium-Term Pace | Covariates=CPI
#    ✅ MAPE=0.83% | MAE=58.72
# [▶] IHSG | Medium-Term Pace | Covariates=Unemployment
#    ✅ MAPE=0.83% | MAE=58.70
# [▶] IHSG | Medium-Term Pace | Covariates=USD
#    ✅ MAPE=0.84% | MAE=58.82
# [▶] IHSG | Medium-Term Pace | Covariates=Brent
#    ✅ MAPE=0.83% | MAE=58.71
# [▶] IHSG | Medium-Term Pace | Covariates=WTI
#    ✅ MAPE=0.83% | MAE=58.73
# [▶] IHSG | Long-Term Marathon | Covariates=None
#    ✅ MAPE=1.22% | MAE=85.99
# [▶] IHSG | Long-Term Marathon | Covariates=Domestic
#    ✅ MAPE=1.54% | MAE=108.82
# [▶] IHSG | Long-Term Marathon | Covariates=Global
#    ✅ MAPE=1.22% | MAE=85.97
# [▶] IHSG | Long-Term Marathon | Covariates=All
#    ✅ MAPE=1.72% | MAE=121.38
# [▶] IHSG | Long-Term Marathon | Covariates=Inflation
#    ✅ MAPE=1.22% | MAE=85.99
# [▶] IHSG | Long-Term Marathon | Covariates=GDP
#    ✅ MAPE=1.55% | MAE=109.87
# [▶] IHSG | Long-Term Marathon | Covariates=CPI
#    ✅ MAPE=1.22% | MAE=85.99
# [▶] IHSG | Long-Term Marathon | Covariates=Unemployment
#    ✅ MAPE=1.22% | MAE=85.99
# [▶] IHSG | Long-Term Marathon | Covariates=USD
#    ✅ MAPE=1.22% | MAE=86.00
# [▶] IHSG | Long-Term Marathon | Covariates=Brent
#    ✅ MAPE=1.22% | MAE=85.93
# [▶] IHSG | Long-Term Marathon | Covariates=WTI
#    ✅ MAPE=1.22% | MAE=85.81
#
# 📂 Processing LQ45
# [▶] LQ45 | Short-Term Sprint | Covariates=None
#    ✅ MAPE=0.63% | MAE=6.04
# [▶] LQ45 | Short-Term Sprint | Covariates=Domestic
#    ✅ MAPE=0.64% | MAE=6.05
# [▶] LQ45 | Short-Term Sprint | Covariates=Global
#    ✅ MAPE=0.65% | MAE=6.17
# [▶] LQ45 | Short-Term Sprint | Covariates=All
#    ✅ MAPE=0.65% | MAE=6.19
# [▶] LQ45 | Short-Term Sprint | Covariates=Inflation
#    ✅ MAPE=0.64% | MAE=6.05
# [▶] LQ45 | Short-Term Sprint | Covariates=GDP
#    ✅ MAPE=0.64% | MAE=6.06
# [▶] LQ45 | Short-Term Sprint | Covariates=CPI
#    ✅ MAPE=0.63% | MAE=6.04
# [▶] LQ45 | Short-Term Sprint | Covariates=Unemployment
#    ✅ MAPE=0.64% | MAE=6.05
# [▶] LQ45 | Short-Term Sprint | Covariates=USD
#    ✅ MAPE=0.65% | MAE=6.19
# [▶] LQ45 | Short-Term Sprint | Covariates=Brent
#    ✅ MAPE=0.63% | MAE=6.04
# [▶] LQ45 | Short-Term Sprint | Covariates=WTI
#    ✅ MAPE=0.64% | MAE=6.06
# [▶] LQ45 | Medium-Term Pace | Covariates=None
#    ✅ MAPE=1.02% | MAE=9.69
# [▶] LQ45 | Medium-Term Pace | Covariates=Domestic
#    ✅ MAPE=1.02% | MAE=9.69
# [▶] LQ45 | Medium-Term Pace | Covariates=Global
#    ✅ MAPE=1.03% | MAE=9.80
# [▶] LQ45 | Medium-Term Pace | Covariates=All
#    ✅ MAPE=1.03% | MAE=9.82
# [▶] LQ45 | Medium-Term Pace | Covariates=Inflation
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Medium-Term Pace | Covariates=GDP
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Medium-Term Pace | Covariates=CPI
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Medium-Term Pace | Covariates=Unemployment
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Medium-Term Pace | Covariates=USD
#    ✅ MAPE=1.04% | MAE=9.85
# [▶] LQ45 | Medium-Term Pace | Covariates=Brent
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Medium-Term Pace | Covariates=WTI
#    ✅ MAPE=1.02% | MAE=9.68
# [▶] LQ45 | Long-Term Marathon | Covariates=None
#    ✅ MAPE=1.45% | MAE=13.81
# [▶] LQ45 | Long-Term Marathon | Covariates=Domestic
#    ✅ MAPE=1.81% | MAE=17.35
# [▶] LQ45 | Long-Term Marathon | Covariates=Global
#    ✅ MAPE=1.46% | MAE=13.90
# [▶] LQ45 | Long-Term Marathon | Covariates=All
#    ✅ MAPE=1.81% | MAE=17.40
# [▶] LQ45 | Long-Term Marathon | Covariates=Inflation
#    ✅ MAPE=1.45% | MAE=13.81
# [▶] LQ45 | Long-Term Marathon | Covariates=GDP
#    ✅ MAPE=1.80% | MAE=17.24
# [▶] LQ45 | Long-Term Marathon | Covariates=CPI
#    ✅ MAPE=1.45% | MAE=13.81
# [▶] LQ45 | Long-Term Marathon | Covariates=Unemployment
#    ✅ MAPE=1.45% | MAE=13.81
# [▶] LQ45 | Long-Term Marathon | Covariates=USD
#    ✅ MAPE=1.46% | MAE=13.93
# [▶] LQ45 | Long-Term Marathon | Covariates=Brent
#    ✅ MAPE=1.45% | MAE=13.80
# [▶] LQ45 | Long-Term Marathon | Covariates=WTI
#    ✅ MAPE=1.45% | MAE=13.81
#
# 📂 Processing KOMPAS100
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=None
#    ✅ MAPE=0.61% | MAE=7.13
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=Domestic
#    ✅ MAPE=0.62% | MAE=7.33
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=Global
#    ✅ MAPE=0.62% | MAE=7.30
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=All
#    ✅ MAPE=0.64% | MAE=7.47
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=Inflation
#    ✅ MAPE=0.61% | MAE=7.12
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=GDP
#    ✅ MAPE=0.62% | MAE=7.31
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=CPI
#    ✅ MAPE=0.61% | MAE=7.13
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=Unemployment
#    ✅ MAPE=0.61% | MAE=7.15
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=USD
#    ✅ MAPE=0.62% | MAE=7.26
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=Brent
#    ✅ MAPE=0.61% | MAE=7.12
# [▶] KOMPAS100 | Short-Term Sprint | Covariates=WTI
#    ✅ MAPE=0.61% | MAE=7.13
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=None
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=Domestic
#    ✅ MAPE=0.97% | MAE=11.39
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=Global
#    ✅ MAPE=1.42% | MAE=16.65
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=All
#    ✅ MAPE=1.42% | MAE=16.62
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=Inflation
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=GDP
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=CPI
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=Unemployment
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=USD
#    ✅ MAPE=1.28% | MAE=15.04
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=Brent
#    ✅ MAPE=0.97% | MAE=11.39
# [▶] KOMPAS100 | Medium-Term Pace | Covariates=WTI
#    ✅ MAPE=0.97% | MAE=11.38
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=None
#    ✅ MAPE=1.41% | MAE=16.58
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=Domestic
#    ✅ MAPE=1.42% | MAE=16.74
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=Global
#    ✅ MAPE=1.48% | MAE=17.40
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=All
#    ✅ MAPE=1.52% | MAE=17.86
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=Inflation
#    ✅ MAPE=1.41% | MAE=16.58
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=GDP
#    ✅ MAPE=1.42% | MAE=16.74
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=CPI
#    ✅ MAPE=1.41% | MAE=16.58
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=Unemployment
#    ✅ MAPE=1.41% | MAE=16.58
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=USD
#    ✅ MAPE=1.42% | MAE=16.74
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=Brent
#    ✅ MAPE=1.41% | MAE=16.58
# [▶] KOMPAS100 | Long-Term Marathon | Covariates=WTI
#    ✅ MAPE=1.41% | MAE=16.57
#
# ✅ All experiments done! Saved to C:\wilson\Thesis\Results\rf_results_summary_20260106_2146.csv
